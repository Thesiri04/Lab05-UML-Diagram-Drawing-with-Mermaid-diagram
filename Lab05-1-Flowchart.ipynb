// %% [markdown]
// # Lab 5.1 การวาด flowchart ด้วย mermaid diagram

// %% [markdown]
// ## 5
// .1.1 องค์ประกอบต่างๆ ของการวาด flowchart

// %% [markdown]
// ศึกษาจากตัวอย่างแผนภาพอย่างง่ายต่อไปนี้ โดยการรัน code cell ด้านล่างนี้ (โดยการเข้าไปใน cell แล้วกด Ctrl+Enter)
//
// __หมายเหตุ__ นักศึกษาสามารถล้างผลการรันทั้งหมดได้โดยการกดปุ่ม _Clear All Outputs_  ที่ด้านบนของเอกสาร

// %%
%% Example 1. Flow chart
flowchart TD
    A[Start] --> B{Today = Workday}
    B -- Yes --> C[Goto school]
    B -- No --> D[Goto picnic]
    C --> E[Back to home]
    D --> E
    E --> F[End]
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="4afb266d3e8e4822844d4910c6703772"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('4afb266d3e8e4822844d4910c6703772');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_4afb266d3e8e4822844d4910c6703772',
//                     `%% Example 1. Flow chart
// flowchart TD
//     A[Start] --> B{Today = Workday}
//     B -- Yes --> C[Goto school]
//     B -- No --> D[Goto picnic]
//     C --> E[Back to home]
//     D --> E
//     E --> F[End]`);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// ### อธิบาย Code ตามรูปแบบสัญลักษณ์ที่ปรากฏใน code
// จาก code และรูปที่ได้จากการรัน สามารถอธิบายส่วนต่างๆ ตามไวยากรณ์ได้ดังนี้
//
// 1. `flowchart TD` ป็นคำสั่งที่ใช้ในการสร้าง แผนภูมิลำดับขั้นตอน (flowchart) ที่มีทิศทางจาก บนลงล่าง (top-down)
// 2. `A[start]` เป็นการกำหนดโหนด A ที่มีลักษณะเป็นกล่องสี่เหลี่ยม มีคำว่า Start อยู่ด้านใน
// 3. `-->` เป็นการระบุว่าลากเส้นลูกศรจากโหนด A ไปโหนด B
// 4. `B{Today = Workday}` เป็นการสร้างโหนด B ซึ่งเป็นบล็อกของการตัดสินใจ
// 5. `-- Yes --> หรือ -- NO -->` เป็นการลากเส้นลูกศรที่มีข้อความ Yes หรือ No กำกับ

// %% [markdown]
// คักลอก code จากตัวอย่าง Example 1 มาไว้ในพื้นที่แก้ไข code ด้านล่าง แล้วแก้ไข code ตามนี้
// > ```diff
// > - flowchart TD
// > + flowchart LR
// > ```

// %% [markdown]
// _หมายเหตุ_ จากคำสั่งด้านบน หมายความว่า ให้ลบบรรทัด flowchart TD แล้วเพิ่ม flowchart LR ที่ตำแหน่งเดิม
//
// หมายถึงการแก้ไขบรรทัดนั้นจาก flowchart TD เป็น flowchart LR นั่นเอง
//
// ซึ่งเป็นรูปแบบของการระบุการเปลี่ยนแปลงเนื้อหาใน git

// %%
%% Example 1. Flow chart
flowchart LR
    A[Start] --> B{Today = Workday}
    B -- Yes --> C[Goto school]
    B -- No --> D[Goto picnic]
    C --> E[Back to home]
    D --> E
    E --> F[End]
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="2f95711ae8fd42d5a758d84f5e68ecf7"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('2f95711ae8fd42d5a758d84f5e68ecf7');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_2f95711ae8fd42d5a758d84f5e68ecf7',
//                     `%% Example 1. Flow chart
// flowchart LR
//     A[Start] --> B{Today = Workday}
//     B -- Yes --> C[Goto school]
//     B -- No --> D[Goto picnic]
//     C --> E[Back to home]
//     D --> E
//     E --> F[End]`);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// หมายเหตุ ถ้ารันไม่ได้ หรือมี error เช่นในลักษณะนี้
// > ```
// > Error: (1,1): error CS1525: Invalid expression term '%'
// > (1,2): error CS1525: Invalid expression term '%'
// > (1,17): error CS1002: ; expected
// > ```
//
// ปัญหาเกิดจากการเลือกภาษาเป็น csharp ให้คลิกเลือกภาษาจากมุมขวาล่างของ code cell โดยเปลี่ยนเป็นภาษา mermaid

// %% [markdown]
// #### คำถาม
//
// 1. บรรทัดที่ขึ้นต้นด้วย %% มีการแแสดงผลที่ output หรือไม่ ถ้ามี จะแสดงอย่างไร
// 2. บอกข้อแตกต่างระหว่าง flowchart TD และ flowchart LR

// %% [markdown]
// 1. มีการแสดงผลโดยตรงบน diagram ที่สร้างขึ้นมา
// 2. TD หมายถึงการวางแผนภูมิลำดับขั้นตอนในแนวตั้ง โดยเริ่มจากด้านบนแล้วไหลลงมาด้านล่าง คิดง่ายๆ คล้ายกับการอ่านหนังสือจากบนลงล่าง
// LR หมายถึงการวางแผนภูมิลำดับขั้นตอนในแนวนอน โดยเริ่มจากด้านซ้ายแล้วไหลไปทางขวา คล้ายกับการอ่านหนังสือจากซ้ายไปขวา

// %% [markdown]
// ---

// %% [markdown]
// ## Flowcharts - Basic Syntax

// %% [markdown]
// #### 1 Node

// %% [markdown]
// รัน code cell ด้านล่าง เพื่อดูผลที่ได้ และตอบคำถาม

// %% [markdown]
// _Example 2_

// %%
---
title: Node
---
flowchart LR
    id
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="c8ca57bf058d41e8854ab5b4242cd426"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('c8ca57bf058d41e8854ab5b4242cd426');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_c8ca57bf058d41e8854ab5b4242cd426',
//                     `---
// title: Node
// ---
// flowchart LR
//     id`);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// __คำถาม__
//
// 1. ข้อความต่อไปนี้คืออะไร มีการแสดงที่ output หรือไม่
// > ```
// > ---
// > title: Node
// > ---
// > ```
//
// 2. ข้อความ id มีการแสดงนำไปแสดงผลที่ output หรือไม่ แสดงเป็นอะไร

// %% [markdown]
// 1. ไม่แสดงผล
// 2. ไม่ได้แสดงผลโดยตรงบน diagram: แต่ใช้เป็นตัวระบุภายในสำหรับอ้างอิงถึงส่วนต่างๆ ของ diagram

// %% [markdown]
// ---

// %% [markdown]
// #### 2. Node ที่มีข้อความกำกับ

// %% [markdown]
// จาก Example 2 ให้แก้ข้อความดังนี้
// > ```diff
// > ---
// > title: Node
// > ---
// > flowchart LR
// > -    id
// > +    id[Happy New Year]
// > ```

// %%
---
title: Node
---
flowchart LR
    id[Happy New Year]
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="e91a5ad3b7f5457dac6954dd156e38e3"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('e91a5ad3b7f5457dac6954dd156e38e3');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_e91a5ad3b7f5457dac6954dd156e38e3',
//                     `---
// title: Node
// ---
// flowchart LR
//     id[Happy New Year] `);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// จาก code ด้านบน  ให้แก้เป็นดังต่อไปนี้
// > ```diff
// > ---
// > title: Node
// > ---
// > flowchart LR
// > -    id[Happy New Year]
// > +    id [Happy New Year]
// > ```

// %%
---
title: Node
---
flowchart LR
    id [Happy New Year]
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="481aefb3d3d744d1b5af76bfbacddcbc"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('481aefb3d3d744d1b5af76bfbacddcbc');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_481aefb3d3d744d1b5af76bfbacddcbc',
//                     `---
// title: Node
// ---
// flowchart LR
//     id [Happy New Year] `);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// __คำถาม__
//
// เมื่อรัน code cell ด้านบน ผลที่ได้แตกต่างจาก Example 2  อย่างไร

// %% [markdown]
// 1. จะสร้างโปรแกรมได้ผลลัพธ์ต่างกัน ตัวอย่างที่ 2 จะแสดงสี่เหลี่ยมที่มีคำว่า id
// 2. แต่ code cell ด้านบทจะไม่แสดงผล

// %% [markdown]
// ---

// %% [markdown]
// #### 3. การกำหนดทิศทางของ flow

// %% [markdown]
// สร้าง code cell และเขียน code ภาษา mermaid ดังนี้
// > ```
// > flowchart TD
// >     Start --> Stop
// > ```

// %%
flowchart TD
    Start --> Stop
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="84ca9dce20a24c6684c1aaefbefe0604"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('84ca9dce20a24c6684c1aaefbefe0604');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_84ca9dce20a24c6684c1aaefbefe0604',
//                     `flowchart TD
//     Start --> Stop`);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// แก้ไข code ด้านบนดังนี้
// > ```diff
// > - flowchart TD
// > + flowchart LR
// >     Start --> Stop
// > ```

// %%
flowchart LR
    Start --> Stop
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="70f9e3b5f4a847a2b019c9ff37d821eb"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('70f9e3b5f4a847a2b019c9ff37d821eb');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_70f9e3b5f4a847a2b019c9ff37d821eb',
//                     `flowchart LR
//     Start --> Stop`);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// ___คำถาม___
//
// flowchart TD และ flowchart LR ให้ผลแตกต่างกันอย่างไร

// %% [markdown]
// TD จะเป็นแนวตั้ง LR จะเป็นแนวนอน

// %% [markdown]
// ---

// %% [markdown]
// #### 4. รูปร่างของ Node

// %% [markdown]
// รัน code cell ต่อไปนี้

// %%
flowchart LR
    id1(This is the text in the box)
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="6fa45fd197c843758276fa6d9913cd6d"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('6fa45fd197c843758276fa6d9913cd6d');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_6fa45fd197c843758276fa6d9913cd6d',
//                     `flowchart LR
//     id1(This is the text in the box)`);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// อธิบายรูปร่างที่ได้

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// แก้ไข code ด้านบน เป็นดังต่อไปนี้
// > ```diff
// > flowchart LR
// > -    id1(This is the text in the box)
// > +    d1([This is the text in the box])
// > ```

// %%
flowchart LR
    d1([This is the text in the box])
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="2248a60383cc41eda1c83bec79ac617c"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('2248a60383cc41eda1c83bec79ac617c');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_2248a60383cc41eda1c83bec79ac617c',
//                     `flowchart LR
//     d1([This is the text in the box])`);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// อธิบายรูปร่างที่ได้

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// ให้สร้าง code cell แล้วนำ code จากตารางต่อไปนี้ไปวางใน code cell เหล่านั้น

// %% [markdown]
// |รูปร่าง|เครื่องหมายที่ใช้|Code|
// |---|:---------:|---|
// |วงกลม| ((...))| flowchart LR<br><dd>id1((This is the text in the circle)) </dd>|
// |ทรงกระบอก| [(...)] |  flowchart LR <br> <dd>id1[(Database)]</dd>|
// |ป้ายกำกับ| >...]  |  flowchart LR <br> <dd>id1>This is the text in the box]</dd>|
// |การตัดสินใจ |{...} |  flowchart LR <br> <dd> id1{This is the text in the box} </dd>|
// |hexagon |{{...}} |  flowchart LR <br> <dd> {{This is the text in the box}} </dd>|
// | Parallelogram|[/.../] |  flowchart LR <br> <dd> id1[/This is the text in the box/]</dd>|
// | Parallelogram alt| [\...\]|  flowchart LR <br> <dd> id1[\This is the text in the box\]</dd>|
// |Trapezoid | [/...\]|  flowchart LR <br> <dd>A[/Christmas\]  </dd>|
// |Trapezoid alt | [\.../]|  flowchart LR <br> <dd>B[\Go shopping/]  </dd>|
// |Double circle| (((...)))|  flowchart LR <br> <dd> id1(((This is the text in the circle))) </dd>|

// %% [markdown]
// ## แบบฝึดหัด
//
// 1. ให้ค้นหา flowchart จาก internet มา 3 ภาพ ที่วาดขึ้นโดยโปรแกรมอื่นที่ไม่ใช่ mermaid  โดยมีองค์ประกอบในไดอะแกรมไม่น้อยกว่า 5 ชิ้นส่วน
// 2. เขียน code ในภาษา mermaid diagram เพื่อวาดตามไดอะแกรมนั้น
// 3. นำภาพที่ได้เทียบกับต้นฉบับ โดย capture เป็น png แล้วแนบลิ้งค์มาในไฟล์ ipynb นี้ (อย่าวางภาพลงไปโดยการ copy & paste เนื่องจากจะทำให้ไฟล์ ipynb มีขนาดที่โตเกินไป)

// %%
flowchart LR
    A((Start)) --> B[Declare variables n1, n2 and sum]
    B --> C[Read n1 and n2]
    C --> D[sum <- n1 + n2]
    D --> E[Display sum]
    E --> F((Stop))
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="7ba0e7272adc4b94a1719be29ce4888e"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('7ba0e7272adc4b94a1719be29ce4888e');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_7ba0e7272adc4b94a1719be29ce4888e',
//                     `flowchart LR
//     A((Start)) --> B[Declare variables n1, n2 and sum]
//     B --> C[Read n1 and n2]
//     C --> D[sum <- n1 + n2]
//     D --> E[Display sum]
//     E --> F((Stop))`);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// ![![image.png](attachment:image.png)](attachment:image.png)

// %% [markdown]
// ![image.png](attachment:image.png)

// %%
flowchart LR
    A((Start Loop)) --> B{Condition}
    B -- Yes --> C[Execute Statement]
    C --> D[Increment or Decrement]
    D --> B
    B -- No --> E((End Loop))
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="0442744f613543f3a89e3a8410237db2"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('0442744f613543f3a89e3a8410237db2');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_0442744f613543f3a89e3a8410237db2',
//                     `flowchart LR
//     A((Start Loop)) --> B{Condition}
//     B -- Yes --> C[Execute Statement]
//     C --> D[Increment or Decrement]
//     D --> B
//     B -- No --> E((End Loop))`);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// ![image.png](attachment:image.png)

// %%
flowchart LR
    A((Start)) --> B[Input Number]
    B --> C{Number % 2 == 0?}
    C -- Yes --> D[Even Number]
    C -- No --> E[Odd Number]
    D --> F((End))
    E --> F
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="cc82245865154974812dd742dfe7c70d"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('cc82245865154974812dd742dfe7c70d');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_cc82245865154974812dd742dfe7c70d',
//                     `flowchart LR
//     A((Start)) --> B[Input Number]
//     B --> C{Number % 2 == 0?}
//     C -- Yes --> D[Even Number]
//     C -- No --> E[Odd Number]
//     D --> F((End))
//     E --> F`);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// ### ศึกษาเพิ่มเติม
//
// https://mermaid.js.org/syntax/flowchart.html
