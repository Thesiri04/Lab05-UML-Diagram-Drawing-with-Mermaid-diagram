// %% [markdown]
// # Lab 5.2 การวาด class diagram ด้วย mermaid diagram

// %% [markdown]
// ## 5.2.1 องค์ประกอบใน class diagram

// %% [markdown]
// ### 1. Class

// %% [markdown]
// การวาด class diagram ใน mermaid มี keywords ที่สำคัญคือ
// 1. ต้องระบุ __ชนิดของไดะแกรม__ ด้วยคีย์เวิร์ด `classDiagram`
// 2. ต้องระบุ __ชื่อคลาส__ ด้วยคีย์เวิร์ด `class`

// %%
classDiagram
    class Animal
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="550168c444534a18aa7d5a111cec02f1"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('550168c444534a18aa7d5a111cec02f1');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_550168c444534a18aa7d5a111cec02f1',
//                     `classDiagram
//     class Animal
// `);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// แก้ code จากด้านบนเป็น
// > ```diff
// > classDiagram
// > -    class Animal
// > +    class Vehicle
// > +    class Computer
// > ```

// %%
classDiagram
    class Vehicle
    class Computer
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="0c698118488a414aa539f704c0577578"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('0c698118488a414aa539f704c0577578');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_0c698118488a414aa539f704c0577578',
//                     `classDiagram
//     class Vehicle
//     class Computer`);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// ---

// %% [markdown]
// ### 2. Class label

// %% [markdown]
// โดยปกติ ชื่อคลาสต้องไม่มีช่องว่างภายในชื่อ ในกรณีที่ต้องการระบุชื่อคลาสที่อ่านง่ายขึ้น เราสามารถใส่ label สำหรับคลาสได้

// %%
classDiagram
    class Animal["Animal with a label"]
    class Dog["Dog is animal"]

Animal <|-- Dog
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="f6dbaa238e23444abadee17ee59666e1"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('f6dbaa238e23444abadee17ee59666e1');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_f6dbaa238e23444abadee17ee59666e1',
//                     `classDiagram
//     class Animal["Animal with a label"]
//     class Dog["Dog is animal"]
//
// Animal <|-- Dog
// `);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// ### การเพิ่มสมาชิกของคลาส
//
// Mermaid  มีรูปแบบในการเขียน code เพื่อระบุประเภทของสมาชิก ดังนี้
// 1. การระบุตัวแปร (variables, fields, หรือ prpoerties)  ทำได้โดยการเขียนชื่อตัวแปร และ/หรือ ชนิด
// 2. การระบุ method ทำได้โดยการเขียนชื่อ method ตามด้วยวงเล็บ
//
// เช่น
// > ```mermaid
// > classDiagram
// > class BankAccount
// > BankAccount : +String owner
// > BankAccount : +BigDecimal balance
// > BankAccount : +deposit(amount)
// > BankAccount : +withdrawal(amount)
// > ```

// %% [markdown]
// ให้นำ code ข้างบนมาใส่ลงใน code cell  แล้วรันเพื่อดูผลลัพธ์

// %%
classDiagram
    class Animal["Animal with a label"]
    class Dog["Dog is animal"]

Animal <|-- Dog
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="57f64461dae94262b1b12a3215198118"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('57f64461dae94262b1b12a3215198118');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_57f64461dae94262b1b12a3215198118',
//                     `classDiagram
//     class Animal["Animal with a label"]
//     class Dog["Dog is animal"]
//
// Animal <|-- Dog
// `);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// ### การระบุ return type สำหรับ method
// ในโปรแกรม oop ส่วนใหญ่จะเป็นภาษาแบบ strong type นั่นคือต้องมีการระบุชนิดสำหรับการส่งค่ากลับของ method อย่างชัดเจน
// วิธีการเขียนคือให้ใส่ชนิด return ไว้หลังวงเล็บของ method
// > ```diff
// > classDiagram
// > class BankAccount{
// >     +String owner
// >     +BigDecimal balance
// >     +deposit(amount) bool
// >     +withdrawal(amount) int
// > }
// > ```

// %% [markdown]
// เขียน code ตามข้างบนแล้วรันเพื่อดูผลลัพธ์

// %%
classDiagram
class BankAccount{
    +String owner
    +BigDecimal balance
    +deposit(amount) bool
    +withdrawal(amount) int
}
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="bb4dc0ac352f49008a3c2ecc349cf965"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('bb4dc0ac352f49008a3c2ecc349cf965');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_bb4dc0ac352f49008a3c2ecc349cf965',
//                     `classDiagram
// class BankAccount{
//     +String owner
//     +BigDecimal balance
//     +deposit(amount) bool
//     +withdrawal(amount) int
// }`);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// ### การระบุ visibility

// %% [markdown]
// การระบุ visibility ของสมาชิกในคลาส
//
// |สัญลักษณ์|visibility|
// |:--:|--|
// |+ |Public|
// |- |Private|
// |#| Protected|

// %% [markdown]
// คลาส Person เป็นตัวอย่างของคลาสคน ที่ไม่มีใครทราบชื่อ นามสกุล และอายของคนอื่น จนกว่าเขาจะบอกว่าเขาเป็นใคร อายุเท่าไหร่
//
// ถ้าเราอยากทราบข้อมูลส่วนบุคคล ให้ถามเขา (เช่นด้วยเมธอด  TellName, TellFullName และ TellAge เป็นต้น)
//
// ทดสอบไดอะแกรมต่อไปนี้โดยการรันในช่อง code cell ด้านล่าง
//
// ```diff
// >classDiagram
// >  class Person{
// >      -String name
// >      #String lastName
// >      -int age
// >      +TellName() String
// >      +TellFullName() String
// >      +TellAge() int
// >  }
// ```

// %%
classDiagram
  class Person{
      -String name
      #String lastName
      -int age
      +TellName() String
      +TellFullName() String
      +TellAge() int
}
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="b243313f5db2496587ee9aa9092121dd"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('b243313f5db2496587ee9aa9092121dd');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_b243313f5db2496587ee9aa9092121dd',
//                     `classDiagram
//   class Person{
//       -String name
//       #String lastName
//       -int age
//       +TellName() String
//       +TellFullName() String
//       +TellAge() int
// }`);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// ---

// %% [markdown]
// ### การกำหนดเส้นเชื่อมโยงเพื่อแสดงความสัมพันธ์ระหว่างคลาส

// %% [markdown]
// มีรูปแบบการเขียนคือ
//
// [classA][Arrow][ClassB]

// %% [markdown]
// ใน mermaid diagram มีรูปแบบลูกศรที่รองรับแตกต่างกัน 8 รูปแบบ
//
// |Type|	Description|
// |:---:|--------|
// |<\|--	|Inheritance|
// |*--	|Composition|
// |o--	|Aggregation|
// |-->	|Association|
// |--	|Link (Solid)|
// |..>	|Dependency|
// |..\|>	|Realization|
// |..	|Link (Dashed)|

// %% [markdown]
// เขียน code ต่อไปนี้ลงใน code cell โดยกำหนดภาษาเป็น mermaid แล้วรันเพื่อดูผลที่ได้
// > ```diff
// > classDiagram
// > classA <|-- classB
// > classC *-- classD
// > classE o-- classF
// > classG <-- classH
// > classI -- classJ
// > classK <.. classL
// > classM <|.. classN
// > classO .. classP
// > ```

// %%
classDiagram
classA <|-- classB
classC *-- classD
classE o-- classF
classG <-- classH
classI -- classJ
classK <.. classL
classM <|.. classN
classO .. classP
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="699c32266b4e4973924ebad977ef9383"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('699c32266b4e4973924ebad977ef9383');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_699c32266b4e4973924ebad977ef9383',
//                     `classDiagram
// classA <|-- classB
// classC *-- classD
// classE o-- classF
// classG <-- classH
// classI -- classJ
// classK <.. classL
// classM <|.. classN
// classO .. classP`);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// เราสามารถกำหนดชื่อให้กับลูกศรได้

// %% [markdown]
// เขียน code ต่อไปนี้ลงใน code cell โดยกำหนดภาษาเป็น mermaid แล้วรันเพื่อดูผลที่ได้
// > ```diff
// > classDiagram
// > classA --|> classB : Inheritance
// > classC --* classD : Composition
// > classE --o classF : Aggregation
// > classG --> classH : Association
// > classI -- classJ : Link(Solid)
// > classK ..> classL : Dependency
// > classM ..|> classN : Realization
// > classO .. classP : Link(Dashed)
// > ```

// %% [markdown]
// ห

// %%
classDiagram
classA --|> classB : Inheritance
classC --* classD : Composition
classE --o classF : Aggregation
classG --> classH : Association
classI -- classJ : Link(Solid)
classK ..> classL : Dependency
classM ..|> classN : Realization
classO .. classP : Link(Dashed)
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="9fc2f623d0e744878d00a49d0f3752d2"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('9fc2f623d0e744878d00a49d0f3752d2');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_9fc2f623d0e744878d00a49d0f3752d2',
//                     `classDiagram
// classA --|> classB : Inheritance
// classC --* classD : Composition
// classE --o classF : Aggregation
// classG --> classH : Association
// classI -- classJ : Link(Solid)
// classK ..> classL : Dependency
// classM ..|> classN : Realization
// classO .. classP : Link(Dashed)`);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// ---

// %% [markdown]
// ### Cardinality / Multiplicity on relations

// %% [markdown]
// รูปแบบต่างๆ ของ Cardinality
//
// |Symbol|Description|
// |:----:|----|
// |1 |Only 1|
// |0..1 |Zero or One|
// |1..* |One or more|
// |* |Many|
// |n |n (where n>1)|
// |0..n |zero to n (where n>1)|
// |1..n |one to n (where n>1)|

// %% [markdown]
// วิธีการระบุ cardilanity
//
// `[classA] "cardinality1" [Arrow] "cardinality2" [ClassB]:LabelText`

// %% [markdown]
// เขียน code ต่อไปนี้ลงใน mermaid code cell แล้วรันเพื่อดูผลลัพธ์
// >```diff
// >classDiagram
// >    Customer "1" --> "*" Ticket
// >    Student "1" --> "1..*" Course
// >    Galaxy --> "many" Star
// >```

// %%
classDiagram
    Customer "1" --> "*" Ticket 
    Student "1" --> "1..*" Course 
    Galaxy --> "many" Star
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="42e22d0f8aa14a78973df7f0d743273b"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('42e22d0f8aa14a78973df7f0d743273b');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_42e22d0f8aa14a78973df7f0d743273b',
//                     `
// classDiagram
//     Customer "1" --> "*" Ticket
//     Student "1" --> "1..*" Course
//     Galaxy --> "many" Star`);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// ปรับปรุง code ด้านบน แล้วรันเพื่อดูผลลัพธ์
// >```diff
// >classDiagram
// >-    Customer "1" --> "*" Ticket
// >+    Customer "1" --> "*" Ticket : Buy
// >-    Student "1" --> "1..*" Course
// >+    Student "1" --> "1..*" Course : Register
// >-    Galaxy --> "many" Star
// >+    Galaxy --> "many" Star : Contains
// >```

// %%
classDiagram
    Customer "1" --> "*" Ticket : Buy 
    Student "1" --> "1..*" Course : Register
    Galaxy --> "many" Star : Contains
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="bc2fa4c5dcee4e4d887907e9d011b005"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('bc2fa4c5dcee4e4d887907e9d011b005');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_bc2fa4c5dcee4e4d887907e9d011b005',
//                     `classDiagram
//     Customer "1" --> "*" Ticket : Buy
//     Student "1" --> "1..*" Course : Register
//     Galaxy --> "many" Star : Contains`);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// ## แบบฝึดหัด
//
// 1. ให้ค้นหา class diagram จาก internet มา 3 ภาพ ที่วาดขึ้นโดยโปรแกรมอื่นที่ไม่ใช่ mermaid  โดยมีองค์ประกอบในไดอะแกรมไม่น้อยกว่า 5 ชิ้นส่วน
// 2. เขียน code ในภาษา mermaid diagram เพื่อวาดตามไดอะแกรมนั้น
// 3. นำภาพที่ได้เทียบกับต้นฉบับ โดย capture เป็น png แล้วแนบลิ้งค์มาในไฟล์ ipynb นี้ (อย่าวางภาพลงไปโดยการ copy & paste เนื่องจากจะทำให้ไฟล์ ipynb มีขนาดที่โตเกินไป)

// %%
classDiagram
    class Player {
        +name: string
        +position: string
        +jerseyNumber: int
        +playGame()
        +train()
    }
    class Quarterback {
    }
    class Running_Back {
    }
    class Left_Tackle {
    }
    Player <|-- Quarterback : extends
    Player <|-- Running_Back : extends
    Player <|-- Left_Tackle : extends
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="6db2e353a89d424c9b275a4af5c88cd8"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('6db2e353a89d424c9b275a4af5c88cd8');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_6db2e353a89d424c9b275a4af5c88cd8',
//                     `classDiagram
//     class Player {
//         +name: string
//         +position: string
//         +jerseyNumber: int
//         +playGame()
//         +train()
//     }
//     class Quarterback {
//     }
//     class Running_Back {
//     }
//     class Left_Tackle {
//     }
//     Player <|-- Quarterback : extends
//     Player <|-- Running_Back : extends
//     Player <|-- Left_Tackle : extends`);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// ![image.png](attachment:image.png)
// ![image-2.png](attachment:image-2.png)

// %%
classDiagram
    class ICommand {
        <<Interface>>
        Execute(): void
    }
    class IEveShunt {
        <<Interface>>
        setSource()
        setTarget()
        getFeetBack()
    }
    class IEveService {
        <<Interface>>
        getServiceName()
    }
    class Frame {
    }
    class Share {
    }

    ICommand <|.. IEveService : implements
    IEveShunt <|.. IEveService : implements
    Frame .-- IEveService : uses
    Share .-- IEveService : uses
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="34893e691e4a423682df52a479b82bd0"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('34893e691e4a423682df52a479b82bd0');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_34893e691e4a423682df52a479b82bd0',
//                     `classDiagram
//     class ICommand {
//         <<Interface>>
//         Execute(): void
//     }
//     class IEveShunt {
//         <<Interface>>
//         setSource()
//         setTarget()
//         getFeetBack()
//     }
//     class IEveService {
//         <<Interface>>
//         getServiceName()
//     }
//     class Frame {
//     }
//     class Share {
//     }
//
//     ICommand <|.. IEveService : implements
//     IEveShunt <|.. IEveService : implements
//     Frame .-- IEveService : uses
//     Share .-- IEveService : uses`);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %%
classDiagram
    class Student {
        - id: int
        - name: string
        - age: int
        + enrollCourse(course: Course): void
        + getDetails(): string
    }

    class Course {
        - courseCode: string
        - courseName: string
        - credits: int
        + addStudent(student: Student): void
        + getInfo(): string
    }

    class Department {
        - deptName: string
        - deptCode: string
        + assignCourse(course: Course): void
    }

    Student --> Course : enrolls in
    Course --> Department : belongs to
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="7e9c8329bbe74a7a8b9f7b303ec6b615"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('7e9c8329bbe74a7a8b9f7b303ec6b615');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_7e9c8329bbe74a7a8b9f7b303ec6b615',
//                     `classDiagram
//     class Student {
//         - id: int
//         - name: string
//         - age: int
//         + enrollCourse(course: Course): void
//         + getDetails(): string
//     }
//
//     class Course {
//         - courseCode: string
//         - courseName: string
//         - credits: int
//         + addStudent(student: Student): void
//         + getInfo(): string
//     }
//
//     class Department {
//         - deptName: string
//         - deptCode: string
//         + assignCourse(course: Course): void
//     }
//
//     Student --> Course : enrolls in
//     Course --> Department : belongs to
// `);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// ![image.png](attachment:image.png)

// %%
classDiagram
    class Book {
        - bookId: int
        - title: string
        - author: string
        - isAvailable: bool
        + borrow(): void
        + returnBook(): void
    }

    class Member {
        - memberId: int
        - name: string
        - email: string
        + borrowBook(book: Book): void
        + returnBook(book: Book): void
    }

    class Librarian {
        - employeeId: int
        - name: string
        - position: string
        + addBook(book: Book): void
        + removeBook(book: Book): void
    }

    Member --> Book : borrows
    Librarian --> Book : manages
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="45b1c013a3a645c69d23224b5a02b228"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('45b1c013a3a645c69d23224b5a02b228');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_45b1c013a3a645c69d23224b5a02b228',
//                     `classDiagram
//     class Book {
//         - bookId: int
//         - title: string
//         - author: string
//         - isAvailable: bool
//         + borrow(): void
//         + returnBook(): void
//     }
//
//     class Member {
//         - memberId: int
//         - name: string
//         - email: string
//         + borrowBook(book: Book): void
//         + returnBook(book: Book): void
//     }
//
//     class Librarian {
//         - employeeId: int
//         - name: string
//         - position: string
//         + addBook(book: Book): void
//         + removeBook(book: Book): void
//     }
//
//     Member --> Book : borrows
//     Librarian --> Book : manages`);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// ![image.png](attachment:image.png)
