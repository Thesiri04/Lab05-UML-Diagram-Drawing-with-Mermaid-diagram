// %% [markdown]
// # Lab 5.3 การวาด sequence diagram ด้วย mermaid diagram

// %% [markdown]
// ### 5.3.1 องค์ประกอบของ sequence diagram
//
// * Class หรือ Object
//   - เขียนแทนด้วย รูปสี่เหลี่ยม
//   - ภายในกรอบมีชื่อของ object/class ในรูปแบบ {Object}:Class
//   - {Object} หมายถึง การระบุหรือไม่ระบุ object ก็ได้
//
// * เส้นแสดงลำดับเวลา
//
//     - แทนด้วย เส้นตรงประแนวตั้ง
//     - เวลาจะเดินจากด้านบนมาสู่ด้านล่าง
//     - กิจกรรมบนสุดถือเป็นกิจกรรมแรก และกิจกรรมที่อยู่ต่ำลงมาจะเป็นกิจกรรมที่เกิดขึ้นต่อจากนั้น
//
// * เส้นแสดงกิจกรรม
//
//     - แทนด้วย ลูกศรแนวนอน
//     - ชี้จาก class/object หนึ่งไปยัง class/object ตัวต่อไป
//     - ชื่อของกิจกรรมจะต้องเป็น Function ที่มีอยู่ใน
//     - class/object ที่ลูกศรชี้ไป
//     - ชื่อจะอยู่ในรูปแบบ {[Condition]}Function

// %% [markdown]
// ### 5.3.2 ประโยชน์ของ Sequence Diagram
// - ช่วยให้รู้ว่า มี Function ขาดหายไปจาก Class Diagram หรือไม่
// - ช่วยให้พิจาณาได้ว่าควรเพิ่มเติม Function ใน Class Diagram อีกหรือไม่
// - ช่วยให้สามารถปรับปรุง Class Diagram ได้สมบูรณ์ ยิ่งขึ้น

// %% [markdown]
// ### 5.3.3 รูปแบบของลูกศรใน sequence diagram
//
//
// | Type	| Description|
// |:-----:| -----------|
// |->	    |Solid line without arrow  |
// |-->	|Dotted line without arrow|
// |->>	|Solid line with arrowhead|
// |-->>	|Dotted line with arrowhead|
// |<<->>	|Solid line with bidirectional arrowheads (v11.0.0+)|
// |<<-->>	|Dotted line with bidirectional arrowheads (v11.0.0+)|
// |-x	    |Solid line with a cross at the end|
// |--x	|Dotted line with a cross at the end|
// |-)	    |Solid line with an open arrow at the end (async)|
// |--)	|Dotted line with a open arrow at the end (async)|

// %% [markdown]
// -------

// %% [markdown]
// ### 5.3.4 การวาด Sequence diagram

// %% [markdown]
// นำ code ต่อไปนี้ไปใส่ใน  mermaid code cell แล้วรันเพื่อดูผลลัพธ์
// >```diff
// >sequenceDiagram
// >    Alice->>John: Hello John, how are you?
// >    John-->>Alice: Great!
// >    Alice-)John: See you later!
// >```

// %% [markdown]
// #### ตัวอย่าง sequence diagram  ของการใช้ตู้ ATM

// %% [markdown]
// นำ code ต่อไปนี้ไปใส่ใน  mermaid code cell แล้วรันเพื่อดูผลลัพธ์
// > ```diff
// > sequenceDiagram
// >    User->>ATM: Insert card
// >    activate ATM
// >    ATM-->>User: Please input PIN
// >    deactivate ATM
// >    User->>ATM: Insert PIN
// >    activate ATM
// >    ATM-->>NetBank: Verify card and PIN
// >    activate NetBank
// >    NetBank-->>Bank: Verify account
// >    activate Bank
// >    Bank-->>NetBank: Invalid account
// >    deactivate Bank
// >    NetBank-->>ATM: Reject card
// >    deactivate NetBank
// >    ATM-->>User: Eject card
// >    deactivate ATM
// >```

// %%
sequenceDiagram
    User->>ATM: Insert card
    activate ATM
    ATM-->>User: Please input PIN
    deactivate ATM
    User->>ATM: Insert PIN
    activate ATM
    ATM-->>NetBank: Verify card and PIN
    activate NetBank
    NetBank-->>Bank: Verify account
    activate Bank
    Bank-->>NetBank: Invalid account
    deactivate Bank
    NetBank-->>ATM: Reject card
    deactivate NetBank
    ATM-->>User: Eject card
    deactivate ATM
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="b45370579dbb4744b265a0cecb0f5b88"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('b45370579dbb4744b265a0cecb0f5b88');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_b45370579dbb4744b265a0cecb0f5b88',
//                     `sequenceDiagram
//     User->>ATM: Insert card
//     activate ATM
//     ATM-->>User: Please input PIN
//     deactivate ATM
//     User->>ATM: Insert PIN
//     activate ATM
//     ATM-->>NetBank: Verify card and PIN
//     activate NetBank
//     NetBank-->>Bank: Verify account
//     activate Bank
//     Bank-->>NetBank: Invalid account
//     deactivate Bank
//     NetBank-->>ATM: Reject card
//     deactivate NetBank
//     ATM-->>User: Eject card
//     deactivate ATM
// `);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// ------

// %% [markdown]
// ## แบบฝึดหัด
//
// 1. ให้ค้นหา sequence diagram จาก internet มา 3 ภาพ ที่วาดขึ้นโดยโปรแกรมอื่นที่ไม่ใช่ mermaid  โดยมีองค์ประกอบในไดอะแกรมไม่น้อยกว่า 5 ชิ้นส่วน
// 2. เขียน code ในภาษา mermaid diagram เพื่อวาดตามไดอะแกรมนั้น
// 3. นำภาพที่ได้เทียบกับต้นฉบับ โดย capture เป็น png แล้วแนบลิ้งค์มาในไฟล์ ipynb นี้ (อย่าวางภาพลงไปโดยการ copy & paste เนื่องจากจะทำให้ไฟล์ ipynb มีขนาดที่โตเกินไป)

// %%
sequenceDiagram
    participant User
    participant Browser
    participant Server
    participant Database

    User->>Browser: เข้าสู่ระบบด้วยชื่อผู้ใช้และรหัสผ่าน
    Browser->>Server: ส่งข้อมูลเข้าสู่ระบบ
    Server->>Database: ตรวจสอบข้อมูลผู้ใช้
    Database-->>Server: ส่งผลการตรวจสอบ (สำเร็จ/ล้มเหลว)
    Server-->>Browser: แสดงผลลัพธ์ (เข้าสู่ระบบสำเร็จ/ไม่สำเร็จ)
    Browser-->>User: แสดงผลให้ผู้ใช้
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="5c0f1a45b5524b73aff53579018667ce"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('5c0f1a45b5524b73aff53579018667ce');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_5c0f1a45b5524b73aff53579018667ce',
//                     `sequenceDiagram
//     participant User
//     participant Browser
//     participant Server
//     participant Database
//
//     User->>Browser: เข้าสู่ระบบด้วยชื่อผู้ใช้และรหัสผ่าน
//     Browser->>Server: ส่งข้อมูลเข้าสู่ระบบ
//     Server->>Database: ตรวจสอบข้อมูลผู้ใช้
//     Database-->>Server: ส่งผลการตรวจสอบ (สำเร็จ/ล้มเหลว)
//     Server-->>Browser: แสดงผลลัพธ์ (เข้าสู่ระบบสำเร็จ/ไม่สำเร็จ)
//     Browser-->>User: แสดงผลให้ผู้ใช้
// `);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// ![image.png](attachment:image.png)

// %%
sequenceDiagram
    participant Customer
    participant WebApp
    participant PaymentGateway
    participant Inventory

    Customer->>WebApp: เลือกสินค้าและยืนยันการสั่งซื้อ
    WebApp->>Inventory: ตรวจสอบสินค้าคงคลัง
    Inventory-->>WebApp: แจ้งสถานะสินค้า (มีในสต็อก/หมด)
    WebApp->>PaymentGateway: ส่งคำร้องขอชำระเงิน
    PaymentGateway-->>WebApp: แจ้งผลการชำระเงิน (สำเร็จ/ล้มเหลว)
    WebApp-->>Customer: แจ้งสถานะการสั่งซื้อ
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="6d71ee1e0d924199b0ac08d8500fa411"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('6d71ee1e0d924199b0ac08d8500fa411');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_6d71ee1e0d924199b0ac08d8500fa411',
//                     `sequenceDiagram
//     participant Customer
//     participant WebApp
//     participant PaymentGateway
//     participant Inventory
//
//     Customer->>WebApp: เลือกสินค้าและยืนยันการสั่งซื้อ
//     WebApp->>Inventory: ตรวจสอบสินค้าคงคลัง
//     Inventory-->>WebApp: แจ้งสถานะสินค้า (มีในสต็อก/หมด)
//     WebApp->>PaymentGateway: ส่งคำร้องขอชำระเงิน
//     PaymentGateway-->>WebApp: แจ้งผลการชำระเงิน (สำเร็จ/ล้มเหลว)
//     WebApp-->>Customer: แจ้งสถานะการสั่งซื้อ
// `);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// ![image.png](attachment:image.png)

// %%
sequenceDiagram
    participant Member
    participant Librarian
    participant LibrarySystem
    participant Database

    Member->>Librarian: ขอทำการยืมหนังสือ
    Librarian->>LibrarySystem: ตรวจสอบสถานะหนังสือ
    LibrarySystem->>Database: ค้นหาข้อมูลหนังสือ
    Database-->>LibrarySystem: ส่งข้อมูลสถานะหนังสือ
    LibrarySystem-->>Librarian: ยืนยันการยืมได้
    Librarian-->>Member: อนุมัติการยืม
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="2c14bf89861b4b349dd9489e459108d6"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('2c14bf89861b4b349dd9489e459108d6');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_2c14bf89861b4b349dd9489e459108d6',
//                     `sequenceDiagram
//     participant Member
//     participant Librarian
//     participant LibrarySystem
//     participant Database
//
//     Member->>Librarian: ขอทำการยืมหนังสือ
//     Librarian->>LibrarySystem: ตรวจสอบสถานะหนังสือ
//     LibrarySystem->>Database: ค้นหาข้อมูลหนังสือ
//     Database-->>LibrarySystem: ส่งข้อมูลสถานะหนังสือ
//     LibrarySystem-->>Librarian: ยืนยันการยืมได้
//     Librarian-->>Member: อนุมัติการยืม
// `);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// ![image.png](attachment:image.png)
